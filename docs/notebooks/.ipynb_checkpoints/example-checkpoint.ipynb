# %% [markdown]
# # Example notebook

# %%
import numpy as np
from anndata import AnnData
import pandas as pd
import knn_normalization
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 from anndata import AnnData
#       3 import pandas as pd
# ----> 4 import knn_normalization
#
# ModuleNotFoundError: No module named 'knn_normalization'

# %% [markdown]
# ## Running KNN normalization with an AnnData object (using neighbors from protein)

# %%
adata = AnnData(np.random.normal(10, size=(100, 20)))

# %%
knn_normalization.tl.knn_normalize_protein(adata)
# Out:
# Implement a preprocessing function here.
# 0
